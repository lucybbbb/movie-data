# %%
import pandas as pd
df = pd.read_excel(r"E:\projects data\movie-data\data\Movie-Data_utf8.xlsx")

#understand data 
df.head()

df.info()

df.columns 

df.shape

#cleaning 

df.isnull().sum()

#remove duplicates

df = df.drop_duplicates()

#clean column names 

df.columns = df.columns.str.lower().str.replace(" ","_")

#validation 

df.describe()
#save cleaned data 

df.to_excel('cleaned_movie-data.xlsx', index = False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 508 entries, 0 to 507
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Movie Title             508 non-null    object
#  1   Release Date            508 non-null    datetime64[ns]
#  2   Wikipedia URL           508 non-null    object
#  3   Genre (1)               508 non-null    object
#  4   Genre (2)               262 non-null    object
#  5   Director (1)            508 non-null    object
#  6   Director (2)            41 non-null     object
#  7   Cast (1)                508 non-null    object
#  8   Cast (2)                503 non-null    object
#  9   Cast (3)                485 non-null    object
#  10  Cast (4)                452 non-null    object
#  11  Cast (5)                389 non-null    object
#  12  Budget ($)              508 non-null    int64
#  13  Box Office Revenue ($)  508 non-null    float64
# ...
